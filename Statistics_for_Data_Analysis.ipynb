# %% [markdown]
# <a href="https://colab.research.google.com/github/Yilap88/Academic-Notes/blob/main/Statistics_for_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STATISTICS FOR DATA ANALYSIS

# %%
# !ls
# Out:
# sample_data

# %%
# Trabaja dentro del repositorio
# %cd /content/sample_data/Academic-Notes

# Guarda los cambios del notebook o scripts
# !git add .
# !git commit -m "Actualización automática desde Colab"
# !git push origin main
# Out:
# [Errno 2] No such file or directory: '/content/sample_data/Academic-Notes'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
